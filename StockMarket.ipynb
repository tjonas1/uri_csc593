# %%
import pandas as pd
import pandas_datareader as web

# %%
#Aktienanalyse
all_data = {ticker: web.get_data_yahoo(ticker)
    for ticker in ['DAI.DE','VNA.DE','PAH3.DE','SHA.DE']}
price = pd.DataFrame({ticker:data ['Adj Close']
                    for ticker, data in all_data.items()})
volume=pd.DataFrame({ticker:data['Volume']
                    for ticker, data in all_data.items()})

# %%
returns = price.pct_change()
returns.tail()
# Out:
#               DAI.DE    VNA.DE   PAH3.DE    SHA.DE
# Date
# 2019-10-15  0.020929  0.024485  0.014259  0.015103
# 2019-10-16  0.015609  0.000629  0.011871  0.021143
# 2019-10-17  0.006660  0.010057  0.013585 -0.003067
# 2019-10-18 -0.014249 -0.004356 -0.004569 -0.000769
# 2019-10-21  0.017140 -0.009583  0.006120  0.016423

# %%
returns.corr()
# Out:
#            DAI.DE    VNA.DE   PAH3.DE    SHA.DE
# DAI.DE   1.000000  0.286767  0.740923  0.575162
# VNA.DE   0.286767  1.000000  0.252292 -0.227939
# PAH3.DE  0.740923  0.252292  1.000000  0.508507
# SHA.DE   0.575162 -0.227939  0.508507  1.000000

# %%
price.tail()
# Out:
#                DAI.DE     VNA.DE    PAH3.DE  SHA.DE
# Date
# 2019-10-15  48.049999  47.700001  64.019997   7.662
# 2019-10-16  48.799999  47.730000  64.779999   7.824
# 2019-10-17  49.125000  48.209999  65.660004   7.800
# 2019-10-18  48.424999  48.000000  65.360001   7.794
# 2019-10-21  49.255001  47.540001  65.760002   7.922

# %%
(price['VNA.DE'][-1]-49)/49
# Out:
# -0.029795899683115433

# %% [raw]
# price['VNA.DE', index='2019-10-21']

# %%
price['2019-10-15':'2019-10-21']
# Out:
#                DAI.DE     VNA.DE    PAH3.DE  SHA.DE
# Date
# 2019-10-15  48.049999  47.700001  64.019997   7.662
# 2019-10-16  48.799999  47.730000  64.779999   7.824
# 2019-10-17  49.125000  48.209999  65.660004   7.800
# 2019-10-18  48.424999  48.000000  65.360001   7.794
# 2019-10-21  49.255001  47.540001  65.760002   7.922

# %%
import matplotlib.pyplot as plt   # Import matplotlib
# This line is necessary for the plot to appear in a Jupyter notebook
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots
 
price['2018-10-21':'2019-10-21'].plot(grid = True) # Plot the prices
returns['2018-10-21':'2019-10-21'].plot(grid = True) # Plot the percent changes
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
returns.tail()
# Out:
#               DAI.DE    VNA.DE   PAH3.DE    SHA.DE
# Date
# 2019-10-15  0.020929  0.024485  0.014259  0.015103
# 2019-10-16  0.015609  0.000629  0.011871  0.021143
# 2019-10-17  0.006660  0.010057  0.013585 -0.003067
# 2019-10-18 -0.014249 -0.004356 -0.004569 -0.000769
# 2019-10-21  0.017140 -0.009583  0.006120  0.016423

# %%
returns.tail().plot(grid = True)
